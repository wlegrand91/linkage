# %%
### Jasco CD output processing
### One stop shop (WIP)

# %%
### Imports

# %%
### Global Vars/Params

data = r""
signals = ["farCD", "nearCD", "phe", "tyr"]

# %%
### Function: Baseline Corrrection

# %%
### Function: LEM

# %%
for signal in signals:
    # Do baseline correction
    # Do

# %%
### Statistical Summary
